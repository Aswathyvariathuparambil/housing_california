# %%
import pandas as pd






df=pd.read_csv(r"D:\aswathyds\housing_california\california_housing.csv")
print(df.head())
# Out:
#   Cell In[10], line 8
#     df=pd.read_csv(rD:\aswathyds\housing_california\california_housing.csv"")
#                      ^
# SyntaxError: invalid syntax
